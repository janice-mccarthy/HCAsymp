# %%
m<-1000
n<-1000

par(mfrow=c(3,1))
for (m in c(100,1000,10000,50000)) {
    U<-rep(0,m)
    for (i in 2:m){
         t <- 1/i
         S <- rbinom(m,n,prob=t)
         W <- (S-n*t)/(sqrt(n*t*(1-t)))
         U[i] <- max(W)
    }
    hist(U,breaks=100)
}
# Out:
# Plot with title “Histogram of U”
# Plot with title “Histogram of U”
